# %%
import requests
from IPython import display
from io import BytesIO
from PIL import Image 
import PIL 
import os
from image_slicer import slice
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-40e6f4279fb6> in <module>
#       5 import PIL
#       6 import os
# ----> 7 from image_slicer import slice
#
# ModuleNotFoundError: No module named 'image_slicer'

# %%
# orig = rabbit drives a race car
# pivot = a cat sitting on a table with a laptop.
input_text =  'A cat sitting on a bench next to a tree.'
label = 'cat_tree'

# %%
r = requests.post(
    "https://api.deepai.org/api/text2img",
    data={
        'text': input_text,
    },
    headers={'api-key': }
)
print(r.json())
# Out:
# {'status': 'Out of free credits - please enter payment info in your dashboard: https://deepai.org/dashboard'}

# %%
image_url = r.json()['output_url']
print(image_url)
display.Image(image_url)
# Out:
# https://api.deepai.org/job-view-file/df7d7bc6-8bd5-4fa6-b758-87ce2c5233fe/outputs/output.jpg

# %%
# Importing Image module from PIL package 
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))
  
# save a image using extension
img = img.save("test/images/test.jpg")

# %%
slice('test/images/test.jpg', 4)
# Out:
# (<Tile #1 - test_01_01.png>,
#  <Tile #2 - test_01_02.png>,
#  <Tile #3 - test_02_01.png>,
#  <Tile #4 - test_02_02.png>)

# %%
# File location
files = ['test_01_01.png','test_02_01.png','test_02_02.png']
location = "~/Desktop/image_paraphraser/test/images"


keep = 'test_01_02.png'
new_name = label +'.jpg'
path = os.path.join(location, keep)
os.rename( path, os.path.join(location,new_name)) 
all = 'test.jpg'
path = os.path.join(location, all)
new_name_all = label + '_all.png'
os.rename( path, os.path.join(location,new_name_all))


for file in files:
    path = os.path.join(location, file)
    os.remove(path)
    print("%s has been removed successfully" %file)
# Out:
# test_01_01.png has been removed successfully
# test_02_01.png has been removed successfully
# test_02_02.png has been removed successfully

# %%
# !python3 Show_and_Tell/main.py --phase=test \
    --model_file='./models/39999.npy'
# Out:
# /usr/local/Caskroom/miniconda/base/envs/image-paraphraser/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/Caskroom/miniconda/base/envs/image-paraphraser/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/Caskroom/miniconda/base/envs/image-paraphraser/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...
